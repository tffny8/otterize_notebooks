# %% [raw]
# # ASSIGNMENT CONFIG
# generate: true
# export_cell:
#     pdf: false
#     force_save: false
#     run_tests: false
# seed:
#     variable: rng_seed
#     autograder_value: 42
#     student_value: 90

# %%
import numpy as np
import matplotlib.pyplot as plt 
rng_seed = 42

# %% [raw]
# # BEGIN QUESTION
# name: q1
# manual: false
# points: 1
# export: true

# %% [markdown]
# **Question 1.** Write a function that takes two positive integers and returns their product.

# %%
def products (x,y):
    # BEGIN SOLUTION 
    return x * y 
    # END SOLUTION

# %%
# BEGIN TESTS
def test_products(products):
    assert products(3,2) == 6
    assert products(0,2) == 0
    assert products(-1, 24) == -24
    
test_products(products) # IGNORE
# END TESTS
